# %% [markdown]
# ### **Primeros Pasos QGIS en Python**

# %%
import pandas as pd
import geopandas as gpd
import matplotlib as plt

# %%
df = pd.read_csv("/content/tabla de atibutos de nmeros.csv")

# %%
df = pd.read_excel("/content/tabla de atibutos de nmeros.xlsx")

# %%
df.head()
# Out:
#    fid  OBJECTID       LocNombre  LocCodigo  idred  \
# 0    1         1  BARRIOS UNIDOS         12      4
# 1    2         2     TEUSAQUILLO         13      4
# 2    3         3   PUENTE ARANDA         16      2
# 3    4         4    LOS MARTIRES         14      3
# 4    5         5      TUNJUELITO          6      1
#
#                       RedIntregr  Shape_Leng  Shape_Le_1  Shape_Area  \
# 0           Territorio Red Norte    0.121180    0.121180    0.000969
# 1           Territorio Red Norte    0.148314    0.148314    0.001156
# 2   Territorio Red Sur Occidente    0.161116    0.161116    0.001410
# 3  Territorio Red Centro Oriente    0.099382    0.099382    0.000530
# 4             Territorio Red Sur    0.210542    0.210542    0.000807
#
#    NUMPOINTS
# 0        201
# 1        864
# 2        197
# 3         77
# 4        107

# %%
print(df["LocBARRIO"].value_counts())
